# %%
# !pip install mwclient
# !pip install mwparserfromhell

# %%
from mwclient import Site
import mwparserfromhell as mwp

# %%
user_agent = "TheataTest (numberticket+cm@proton.me)"
site = Site('coppermind.net', clients_useragent=user_agent)

# %%
page = site.pages['Kaladin']

# %%
print(page.text()[:1000])
# Out:
# {{character
# |image=The Next Ideal.png
# |parents=[[Lirin]], [[Hesina]]
# |siblings=[[Tien]], [[Oroden]]
# |relatives=[[Aesudan]]{{wob ref|10909}}, [[Gavinor]]
# |born=Late {{Rosharan date|1153}}{{wob ref|10572}}
# |abilities={{tag+|windrunner}}, {{tag+|Shardbearer}}
# |bonded=[[Sylphrena]]
# |titles=Highmarshall, Captain of the [[Bridgemen]], Son of Tanavast,{{book ref|sa3|31}}{{book ref|sa4|107}} The Windrunner, The Captain, The Fallen Soldier, Head of the Cobalt Guard<small>(formerly)</small>
# |aliases=Kaladin Stormblessed, Bridgeboy, Kal
# |profession=Soldier, bridgeman <small>(formerly)</small>, bodyguard <small>(formerly)</small>, {{cat tag|Medical professionals|apprentice surgeon}} <small>(formerly)</small>
# ...

# %%
wikicode = mwp.parse(page.text())

# %%
print(wikicode.strip_code())
# Out:
# Kaladin, nicknamed Kal, renowned as Kaladin Stormblessed, is a Windrunner of the Knights Radiant from Alethkar. Despite being trained as a surgeon from an early age by his father, his chosen profession is that of a soldier. He is famed as the captain of Highprince Dalinar Kholin's personal guard, a unit known as Bridge Four, commander of the bridgemen battalion and Highmarshal of the Order of Windrunners.
#
# Kaladin has known adversity and loss throughout his life. He has suffered repeated oppression and betrayal by the lighteyed nobility, including being driven from his home by the citylord of his hometown as a teenager and being sold into slavery by the commander of his army. Kaladin has also been unable to save numerous patients, comrades, subordinates, and even his brother Tien from death.
#
# ...

# %%
for node in wikicode.nodes[1:]:
if type(node) in [mwp.nodes.text.Text, mwp.nodes.wikilink.Wikilink]:
        continue
    if isinstance(node, mwp.nodes.template.Template) and (node.name.strip() == "book ref" or node.name.strip() == "quote" or node.name.strip() == "wob ref"):
        continue
    print(f'Node typ: {type(node)}, content: {node}')
# Out:
# Node typ: <class 'mwparserfromhell.nodes.template.Template'>, content: {{update|sa3|sa4}}
# Node typ: <class 'mwparserfromhell.nodes.tag.Tag'>, content: '''Kaladin'''
# Node typ: <class 'mwparserfromhell.nodes.tag.Tag'>, content: '''Kal'''
# Node typ: <class 'mwparserfromhell.nodes.tag.Tag'>, content: '''Kaladin Stormblessed'''
# Node typ: <class 'mwparserfromhell.nodes.heading.Heading'>, content: == Appearance and Personality ==
# Node typ: <class 'mwparserfromhell.nodes.template.Template'>, content: {{image|Kaladin - XI Justice .jpg|side=right|width=300px|Kaladin the [[Windrunner]]}}
# Node typ: <class 'mwparserfromhell.nodes.heading.Heading'>, content: === Appearance ===
# Node typ: <class 'mwparserfromhell.nodes.template.Template'>, content: {{for|/Gallery|more images}}
# Node typ: <class 'mwparserfromhell.nodes.tag.Tag'>, content: ''[[Glyphs/Index#Sas|sas]] [[Glyphs/Index#Nahn|nahn]]''
# Node typ: <class 'mwparserfromhell.nodes.tag.Tag'>, content: ''shash''
# ...

# %%
class SourceManager:
    def __init__(self, wikiEndpoint='coppermind.net') -> None:
        self.user_agent = "TheataTest (numberticket+cm@proton.me)"
        self.site = Site(wikiEndpoint, clients_useragent=self.user_agent)
    
    def wiki_parse(self, title):
        # Parse wiki pages and return wikicode object from MWParser
        page = self.site.pages[title]
        return mwp.parse(page.text())

# %%
manager = SourceManager()

# %%
page_titles = [
    "Kaladin",
    "Pits of Hathsin",
    "Allomancy",
    "Cosmere",
    "Honor's Perpendicularity",
    "Cephandrius",
]

# %%
pages = []
for title in page_titles:
    pages.append(manager.wiki_parse(title))

# %%
for node in pages[5].nodes
    print(f'Node typ: {type(node)}, content: {node}')
# Out:
# Node typ: <class 'mwparserfromhell.nodes.tag.Tag'>, content: #
# Node typ: <class 'mwparserfromhell.nodes.text.Text'>, content: redirect
# Node typ: <class 'mwparserfromhell.nodes.wikilink.Wikilink'>, content: [[Hoid]]
# Node typ: <class 'mwparserfromhell.nodes.text.Text'>, content:
#
# Node typ: <class 'mwparserfromhell.nodes.wikilink.Wikilink'>, content: [[Category: Aliases]]
# Node typ: <class 'mwparserfromhell.nodes.text.Text'>, content:
#
# Node typ: <class 'mwparserfromhell.nodes.wikilink.Wikilink'>, content: [[Category: nominal redirects]]

# %%
# kal = pages[0]
links = kal.filter_templates()
links
# Out:
# ["{{character\n|image=The Next Ideal.png\n|parents=[[Lirin]], [[Hesina]]\n|siblings=[[Tien]], [[Oroden]]\n|relatives=[[Aesudan]]{{wob ref|10909}}, [[Gavinor]]\n|born=Late {{Rosharan date|1153}}{{wob ref|10572}}\n|abilities={{tag+|windrunner}}, {{tag+|Shardbearer}}\n|bonded=[[Sylphrena]]\n|titles=Highmarshall, Captain of the [[Bridgemen]], Son of Tanavast,{{book ref|sa3|31}}{{book ref|sa4|107}} The Windrunner, The Captain, The Fallen Soldier, Head of the Cobalt Guard<small>(formerly)</small>\n|aliases=Kaladin Stormblessed, Bridgeboy, Kal\n|profession=Soldier, bridgeman <small>(formerly)</small>, bodyguard <small>(formerly)</small>, {{cat tag|Medical professionals|apprentice surgeon}} <small>(formerly)</small>\n|groups={{tag|Knights Radiant}} <small>([[Order of Windrunners|Windrunners]])</small>, {{tag|Bridge Four}}, {{tag+|army|Kholin}}, {{tag+|army|Amaram's}} <small>(formerly)</small>, {{tag+|army|Sadeas}} <small>(formerly)</small>, {{tag+|Kaladin's squad}} <small>(formerly)</small>,
# ...

# %%
def clean_wiki_tags(page):
    """Cleans and formats a list of wiki tags into strings for linking in a graph database.

    Args:
        tags: A list of strings representing wiki tags (e.g., '{{tag|Value}}', '{{tag|a|b|c}}').

    Returns:
        A list of cleaned and formatted tag strings.
    """
    tags = page.filter_templates()
    cleaned_tags = set()

    for tag in tags:
        cleaned_tag = tag.replace('{', '').replace('}', '')

        # Handle specific tag formats
        if cleaned_tag.startswith(("update", "character", "cite", "quote","sidequote", "image", "partial","for")):
            continue
        elif tag.startswith("{{wob ref|"):
            cleaned_tag = f"wob_ref-{cleaned_tag.split('|')[1]}"
        elif tag.startswith("{{book ref|"):
            parts = cleaned_tag.split('|')
            cleaned_tag = "-".join(parts[1:])
        elif tag.startswith("{{tag"):
            # Split on pipe (|) and ignore the 'tag' part
            parts = cleaned_tag.split('|')[1:]

            # Handle "cat tag" or "tag|cat=" cases
            if parts[0] == "cat":
                cleaned_tag = parts[2].split('=')[0]  # Get the category name
            elif parts[0] == "army":
                cleaned_tag = parts[1]
            elif "=" in parts[-1]:
                cleaned_tag = parts[0]  # Get the main tag
            else:
                cleaned_tag = '_'.join(parts)
        else:  # Handle other formats
            # Split on pipe (|) and take only the first part
            parts = cleaned_tag.split('|')
            cleaned_tag = parts[0].replace('#', '_').replace(' ', '_').lower()

        if cleaned_tag in ["cat_tag", "cite"]:
            continue

        if cleaned_tag:
            cleaned_tags.add(cleaned_tag.replace("'s",""))

    return list(cleaned_tags)

def clean_wiki_links(page):
    """Removes aliases and duplicates from a list of MediaWiki links.

    Args:
        links: A list of strings representing MediaWiki links (e.g., '[[Link]]', '[[Link|Alias]]').

    Returns:
        A new list with unique links, aliases removed.
    """
    links = page.filter_wikilinks()
    cleaned_links = []
    seen_links = set()  # Track unique links

    for link in links:
        match = re.match(r'\[\[(.*?)(?:\|.*?)?\]\]', str(link)) 
        if match:
            link_text = match.group(1)  # Extract link text (without alias)
            if link_text not in seen_links:
                cleaned_links.append(link_text)
                seen_links.add(link_text)

    return cleaned_links

def get_links(page):
    out_links = set()
    out_links.update(clean_wiki_links(page))
    out_links.update(clean_wiki_tags(page))
    result = set()
    for name in out_links:
        # Check if the name is a substring of any other name in the set
        is_redundant = any(name in other_name and name != other_name for other_name in out_links)
        if not is_redundant:
            result.add(name)

    return result

get_links(pages[0])
# Out:
# 243
# {'Abrobadar',
#  'Adolin Kholin',
#  'Aesudan Kholin',
#  'Akinah',
#  'Alethi',
#  'Alethkar',
#  'Almighty',
#  'Arik',
#  'Assassin in White',
#  'Awakening',
#  'Azir',
#  'Balsas',
#  'Battle of Narak',
#  'Battle of the Tower',
#  'Bluth',
#  'Braize',
#  'Bridge Four',
#  'Category: Bridgemen',
#  'Category: Viewpoint characters',
#  'Cenn',
#  'Cobalt Guard',
#  'Cognitive Shadow',
#  'Cord',
#  'Coreb',
#  'Cosmere',
#  'Court of Gods',
#  'Cryptic',
#  'Dabbid',
#  'Dalar',
#  'Dalinar Kholin',
#  'Dallet',
#  'Danlan',
#  'Day of Recreance',
#  'Deathbend River',
#  'Deathspren',
#  'Derethil',
#  'Desolation',
#  'Devotary of Mercy',
#  'Dieno',
#  'Dragonsteel Prime',
#  'Dreamstorm',
#  'Drehy',
#  'Dunny',
#  'Durk',
#  'Earless Jaks',
#  'Eastern Crownlands',
#  'Elhokar Kholin',
#  'Elit Ruthar',
#  'Eshonai',
#  'Everstorm',
#  'Fen Rnamdi',
#  'Fleet',
#  'Fourth Bridge',
#  'Fused',
#  'Gare',
#  'Gavilar',
#  'Gavinor',
#  'Gaz',
#  'Glyphs/Index#Nahn',
# ...

# %%
kal.strip_code().splitlines()[10:]
# Out:
# [' Appearance and Personality ',
#  '',
#  ' Appearance ',
#  '',
#  'Kaladin is a very tall man, even tall by Alethi standards, standing approximately 6\'4" in Rosharan feet (nearly seven cosmere standard feet). He is leanly muscular and has multiple scars on his body. He has tan skin and shoulder-length wavy black hair typical of an Alethi. He was born with dark brown eyes, though after swearing the Third Ideal of the Windrunners, his eyes turn a pale, glowing blue whenever he summons Syl as a Shardblade, and for a few hours after he dismisses her. Like most Rosharans, Kaladin\'s eyes have an epicanthic fold. His face is square and firm with strong lines and a proud chin. He prefers to be clean-shaven but during his time as a slave, he grows a long, scraggly beard. He is branded on his forehead with a sas nahn glyphpair indicating his slavery and a shash glyph meaning "dangerous". These brands disappeared after Kaladin swore the Fourth Ideal.',
#  '',
#  ' Personality ',
#  '',
# ...

# %%
title = "Kaladin"
def get_sections(title, page):
    current_section = title
    sections = []
    section_order = 1
    for line in page.strip_code().splitlines():
        if line == '': continue
        if line.startswith(' ') and line.endswith(' '):
            if "Note" in line:
                break
            current_section = line.strip()
            section_order = 1
        else:
            paragraph_data = {
                "title": current_section,
                "content": line,
                "order": section_order,
                "parent": title
            }
            sections.append(paragraph_data)
            section_order += 1
    return sections
get_sections(title, kal)
# Out:
# [{'title': 'Kaladin',
#   'content': "Kaladin, nicknamed Kal, renowned as Kaladin Stormblessed, is a Windrunner of the Knights Radiant from Alethkar. Despite being trained as a surgeon from an early age by his father, his chosen profession is that of a soldier. He is famed as the captain of Highprince Dalinar Kholin's personal guard, a unit known as Bridge Four, commander of the bridgemen battalion and Highmarshal of the Order of Windrunners.",
#   'order': 1,
#   'parent': 'Kaladin'},
#  {'title': 'Kaladin',
#   'content': 'Kaladin has known adversity and loss throughout his life. He has suffered repeated oppression and betrayal by the lighteyed nobility, including being driven from his home by the citylord of his hometown as a teenager and being sold into slavery by the commander of his army. Kaladin has also been unable to save numerous patients, comrades, subordinates, and even his brother Tien from death.',
#   'order': 2,
#   'parent': 'Kaladin'},
#  {'title': 'Kaladin',
# ...

# %%
class SourceManager:
	def __init__(self, wiki_endpoint="coppermind.net") -> None:
		self.user_agent = "TheataTest (numberticket+cm@proton.me)"
		self.site = Site(wiki_endpoint, clients_useragent=self.user_agent)
		self.pages = {}
		self.data = []

	def load_json(self, filename="pages.jsonl"):
		"""Loads data from a JSONLines file, or creates an empty one if it doesn't exist.

		Args:
			filename (str): The name of the JSONLines file. Defaults to "pages.jsonl".

		Returns:
			list: A list of dictionaries loaded from the file, or an empty list if the file didn't exist.
		"""
		data = {}
		try:
			with open(filename, 'r') as file:
				for line in file:
					data.update(json.loads(line))
		except FileNotFoundError:
			# File doesn't exist, create an empty one
			with open(filename, 'w') as file:
				pass  # Do nothing, just create the file

		self.pages = data

	def wiki_parse(self, title) -> dict:
		"""
		parse wiki page and return wiki code obj from MWParser
		"""
		page = self.site.pages[title]
		return {page.name: mwp.parse(page.text())}

	def wiki_parse_pages(self, page_titles, update=False):
		"""
		parse multiple pages, append them to existing list, append them to json w/ raw wikicode objs
		"""
		for title in page_titles:
			if self.pages is {}:
				self.load_json()
			if not update and title in self.pages.keys(): continue
			# ignore cosmere check until after PoC
			self.pages.update(self.wiki_parse(title))
		return self.pages

	def get_sections(self, title, page):
		"""
		loop through each section, create a paragraph dict including the header name, content, section order, and parent article

		returns dict {title: section header,
					  content: list of paragraphs,
					  header order: int,
					  parent: None (assigned outside of func)}
		"""
		# Set intro section title to article title (will this cause problems later?)
		current_section = title
		# init vars
		sections = []
		section_order = 1
		# loop through each line the stripped page
		for line in page.strip_code().splitlines():
			if line == '': continue # skip empty lines
			# if header
			if line.startswith(' ') and line.endswith(' '):
				if "Note" in line:
					break # Notes are just the footnotes. We already captured this in links
				current_section = line.strip()
				section_order = 1
			else:
				# capture paragraph obj
				paragraph_data = {
					"title": current_section,
					"content": line,
					"order": section_order,
					"parent": title
				}
				sections.append(paragraph_data)
				# increment counter
				section_order += 1
		return sections

	def clean_wiki_tags(self, page):
		"""
		Cleans and formats a list of wiki tags into strings for linking in a graph database.
	
		Args:
			tags: A list of strings representing wiki tags (e.g., '{{tag|Value}}', '{{tag|a|b|c}}').
	
		Returns:
			A list of cleaned and formatted tag strings.
		"""
		tags = page.filter_templates()
		cleaned_tags = set()
	
		for tag in tags:
			cleaned_tag = tag.replace('{', '').replace('}', '')
	
			# Handle specific tag formats
			if cleaned_tag.startswith(("update", "character", "cite", "quote","sidequote", "image", "partial","for")):
				continue
			elif tag.startswith("{{wob ref|"):
				cleaned_tag = f"wob_ref-{cleaned_tag.split('|')[1]}"
			elif tag.startswith("{{book ref|"):
				parts = cleaned_tag.split('|')
				cleaned_tag = "-".join(parts[1:])
			elif tag.startswith("{{tag"):
				# Split on pipe (|) and ignore the 'tag' part
				parts = cleaned_tag.split('|')[1:]

				# Handle "cat tag" or "tag|cat=" cases
				if parts[0] == "cat":
					cleaned_tag = parts[2].split('=')[0]  # Get the category name
				elif parts[0] == "army":
					cleaned_tag = parts[1]
				elif "=" in parts[-1]:
					cleaned_tag = parts[0]  # Get the main tag
				else:
					cleaned_tag = '_'.join(parts)
			else:  # Handle other formats
				# Split on pipe (|) and take only the first part
				parts = cleaned_tag.split('|')
				cleaned_tag = parts[0].replace('#', '_').replace(' ', '_').lower()

			if cleaned_tag in ["cat_tag", "cite"]:
				continue

			if cleaned_tag:
				cleaned_tags.add(cleaned_tag.replace("'s",""))

		return list(cleaned_tags)

	def clean_wiki_links(self, page):
		"""Removes aliases and duplicates from a list of MediaWiki links.

		Args:
			links: A list of strings representing MediaWiki links (e.g., '[[Link]]', '[[Link|Alias]]').

		Returns:
			A new list with unique links, aliases removed.
		"""
		links = page.filter_wikilinks()
		cleaned_links = []
		seen_links = set()  # Track unique links

		for link in links:
			match = re.match(r'\[\[(.*?)(?:\|.*?)?\]\]', str(link)) 
			if match:
				link_text = match.group(1)  # Extract link text (without alias)
				if link_text not in seen_links:
					cleaned_links.append(link_text)
					seen_links.add(link_text)

		return cleaned_links

	def get_links(self, page):
		out_links = set()
		out_links.update(clean_wiki_links(page))
		out_links.update(clean_wiki_tags(page))
		result = set()
		for name in out_links:
			# Check if the name is a substring of any other name in the set
			is_redundant = any(name in other_name and name != other_name for other_name in out_links)
			if not is_redundant:
				result.add(name)

		return result

	def process_page(self, page):
		print(f"Processing {page[0]}")
		title = page[0]
		page = page[1]
		if "redirect" in page.strip_code().lower():
			return {
				"title": title,
				"links": self.get_links(page),
				"sections": None,
				}
		article = {
				"title": title,
				"links": self.get_links(page),
				"sections": self.get_sections(title, page),
				}
		return article

	def prep_data_graph(self, page_titles):
		pages = self.wiki_parse_pages(page_titles)
		for page in pages.items():
			prepped_page = self.process_page(page)
			self.data.append(prepped_page)
		return self.data

# %%
manager = SourceManager()

# %%
page_titles = [
    "Kaladin",
    "Pits of Hathsin",
    "Allomancy",
    "Cosmere",
    "Honor's Perpendicularity",
    "Cephandrius",
]

# %%
manager.prep_data_graph(page_titles)
# Out:
# Processing Kaladin
# Processing Pits of Hathsin
# Processing Allomancy
# Processing Cosmere
# Processing Honor's Perpendicularity
# Processing Cephandrius
# [{'title': 'Kaladin',
#   'links': {'Abrobadar',
#    'Adolin Kholin',
#    'Aesudan Kholin',
#    'Akinah',
#    'Alethi',
#    'Alethkar',
#    'Almighty',
#    'Arik',
#    'Assassin in White',
#    'Awakening',
#    'Azir',
#    'Balsas',
#    'Battle of Narak',
#    'Battle of the Tower',
#    'Bluth',
#    'Braize',
#    'Bridge Four',
#    'Category: Bridgemen',
#    'Category: Viewpoint characters',
#    'Cenn',
#    'Cobalt Guard',
#    'Cognitive Shadow',
#    'Cord',
#    'Coreb',
#    'Cosmere',
#    'Court of Gods',
#    'Cryptic',
#    'Dabbid',
#    'Dalar',
#    'Dalinar Kholin',
#    'Dallet',
#    'Danlan',
#    'Day of Recreance',
#    'Deathbend River',
#    'Deathspren',
#    'Derethil',
#    'Desolation',
#    'Devotary of Mercy',
#    'Dieno',
#    'Dragonsteel Prime',
#    'Dreamstorm',
#    'Drehy',
# ...
